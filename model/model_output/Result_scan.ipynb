# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('model_results_scenario_1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    truck_id  bridge_id bridge_condition  bridge_length  \
# 0           0  Truck27360    1002288                D            6.4
# 1           1  Truck27361    1002288                D            6.4
# 2           2  Truck27362    1002288                D            6.4
# 3           3  Truck27363    1002288                D            6.4
# 4           4  Truck27364    1002288                D            6.4
#
#    start_time    end_time  wait_duration
# 0         547  564.565784      17.565784
# 1         552  565.286523      13.286523
# 2         557  572.726253      15.726253
# 3         562  573.180710      11.180710
# 4         567  582.800780      15.800780

# %%
df.groupby('bridge_id').wait_duration.mean()
# Out:
# bridge_id
# 1002288    15.088749
# Name: wait_duration, dtype: float64

# %%
df.bridge_length.mean()
# Out:
# 6.399999999999999

# %%
# Out:
# 0    a
# 1    b
# dtype: object
