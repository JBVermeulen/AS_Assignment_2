# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('model_results_scenario_.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 truck_id  bridge_id bridge_condition  bridge_length  start_time  \
# 0           0   Truck0    1000022                C          397.0          11
# 1           1   Truck1    1000022                C          397.0          16
# 2           2   Truck2    1000022                C          397.0          21
# 3           3   Truck3    1000022                C          397.0          26
# 4           4   Truck4    1000022                C          397.0          31
#
#      end_time  wait_duration
# 0  174.294571     163.294571
# 1  149.806117     133.806117
# 2  148.322094     127.322094
# 3  117.128311      91.128311
# 4  140.600949     109.600949

# %%
df.groupby('bridge_id').wait_duration.mean()
# Out:
# bridge_id
# 1000022    125.166744
# 1000035     14.820319
# 1000046     15.178231
# 1000048     14.991889
# 1000051     36.495664
# 1000055     37.020792
# 1000105     66.565654
# 1000140     15.008711
# 1000167     37.274629
# 1000174     37.420722
# 1000186     14.950194
# 1000208     39.014646
# 1000212     15.057173
# 1000216    128.933813
# 1000224     36.774565
# 1000235     35.992835
# 1000236     34.725877
# 1000248     15.010482
# 1000275     35.807110
# 1000287     15.274342
# 1000318     33.093264
# 1000364     47.457295
# 1000392     39.101075
# 1000393     49.426080
# Name: wait_duration, dtype: float64

# %%
s1 = pd.Series(["a", "b"])
s2 = pd.Series(["c", "d"])
pd.concat([s1, s2])
# Out:
# 0    a
# 1    b
# 0    c
# 1    d
# dtype: object

# %%
s1
# Out:
# 0    a
# 1    b
# dtype: object
