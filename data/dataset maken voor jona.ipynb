# %%
import pandas as pd

# %%
df = pd.read_csv('N1_AS2.csv')

# %%
new_df = df[60:82]

# %%
new_df = new_df.reset_index()

# %%
new_df.loc[0,'model_type'] = 'source'

# %%
new_df.loc[new_df.shape[0]-1,'model_type'] = 'sink'

# %%
new_df
# Out:
#     index road model_type                         name        lat        lon  \
# 0      60   N1     source              Km post missing  23.670916  90.559778
# 1      61   N1       link                  Box culvert  23.670583  90.559972
# 2      62   N1     bridge          MALIBAG BOX CULVERT  23.663309  90.563857
# 3      63   N1       link                  Box culvert  23.670583  90.559972
# 4      64   N1       link              Km post missing  23.662833  90.564111
# 5      65   N1       link      Road to MinanbariZ1061)  23.660417  90.567110
# 6      66   N1       link          Langalbandhu bridge  23.659111  90.569722
# 7      67   N1       link                   Bridge end  23.658306  90.570999
# 8      68   N1       link              Km post missing  23.657500  90.571972
# 9      69   N1       link                 Bridge start  23.655972  90.574333
# 10     70   N1       link                   Bridge end  23.655917  90.574527
# ...

# %%
new_df.to_csv('demo-4.1.csv', index=False)
